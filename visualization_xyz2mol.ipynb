# %%
import numpy as np
import matplotlib

from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw
IPythonConsole.ipython_useSVG=True  #< set this to False if you want PNGs instead of SVGs

from rdkit.Chem import rdFMCS
from rdkit.Chem.Draw import rdDepictor
rdDepictor.SetPreferCoordGen(True)
IPythonConsole.drawOptions.minFontSize=20

# %%
## a is for rdkit

# mol1a=Chem.MolFromSmiles("CN1C=CNC1.CN1C=CNC1.CN1C=CNC1.CN1C=CNC1.S=C=N[Fe]N=C=S")
# mol2a=Chem.MolFromSmiles("CCCC(=O)N1C2CCCCN2[Fe]2(N=C=S)(N=C=S)(N3CCCCC13)N1CCCCC1N(C(=O)CCC)C1CCCCN12")
# mol3a=Chem.MolFromSmiles("O=C[Fe]([PH4])(C=O)(C=O)C=O")
# mol4a=Chem.MolFromSmiles("CC1CC(C)C(N2CCN(C3C(C)CC(C)CC3C)[Fe]2(Cl)Cl)C(C)C1")
# mol5a=Chem.MolFromSmiles("CC1CC(C)C(C2CCC(C3(C)C4CCC(C5C(C)CC(C)CC5C)N4[Fe](N4CCCCC4)(N4CCCCC4)N4C(C5C(C)CC(C)CC5C)CCC43)N2)C(C)C1")
# mol6a=Chem.MolFromSmiles("CC1C(C)C(C)C(C)C1C.CC1CC(C)C(N2C=CN(CC3CCCCN3)C2[Fe]2N=N2)C(C)C1")
# # mol8a=Chem.MolFromSmiles("CCB1C(CC)C(C)[Si](C)(C)N1C.O=C[Fe](C=O)C=O")
# # mol9a=Chem.MolFromSmiles("C=C[SiH](C1CCCCC1CN(C)C)[Fe](C=O)(C=O)(C=O)C=O")
# mol10a=Chem.MolFromSmiles("CC(C)C1CCCC(C(C)C)C1[Se][Fe]([Se]C1C(C(C)C)CCCC1C(C)C)([PH](C)(C)C1CCCCC1)[PH](C)(C)C1CCCCC1")
# mol11a=Chem.MolFromSmiles("CCOC(=O)C12C34CCCCCCC(O3)(C3CCCCC34)C1(C(=O)OCC)[Fe]2(C=O)(C=O)C=O")
# mol12a=Chem.MolFromSmiles("O=C[Fe](C=O)(C=O)C12C3C=CC1(N1CCCCC1)C=CC2(N1CCCCC1)CC3")
# mol13a=Chem.MolFromSmiles("CC1C(C)C(C)C(C)C1C.C[Si](C)(C)C#CC1CCC(C#C[Fe](C=O)C=O)CC1")
# mol14a=Chem.MolFromSmiles("CN(C)P(=O)(C[PH](C=C[Fe](C=O)(C=O)(C=O)C=O)(N(C)C)N(C)C)N(C)C")
# mol15a=Chem.MolFromSmiles("C1CCC(CN2CC3CCCCC3C3CCCCC3C2)NC1.Cl[Fe]Cl")

# %%
#rdkit but with dative

mol1a=Chem.MolFromSmiles("CN1C=CNC1.CN1C=CNC1.CN1C=CNC1.CN1C=CNC1.S=C=N[Fe]N=C=S")
mol2a=Chem.MolFromSmiles("CCCC(=O)N1C2CCCCN2[Fe]2(N=C=S)(N=C=S)(N3CCCCC13)N1CCCCC1N(C(=O)CCC)C1CCCCN12")
mol3a=Chem.MolFromSmiles("O=C[Fe](<-[PH4])(C=O)(C=O)C=O")
mol4a=Chem.MolFromSmiles("CC1CC(C)C(N2CCN(C3C(C)CC(C)CC3C)[Fe]2(Cl)Cl)C(C)C1")
mol5a=Chem.MolFromSmiles("CC1CC(C)C(C2CCC(C3(C)C4CCC(C5C(C)CC(C)CC5C)N4[Fe](N4CCCCC4)(N4CCCCC4)N4C(C5C(C)CC(C)CC5C)CCC43)N2)C(C)C1")
mol6a=Chem.MolFromSmiles("CC1C(C)C(C)C(C)C1C.CC1CC(C)C(N2C=CN(CC3CCCCN3)C2[Fe]2N=N2)C(C)C1")
mol8a=Chem.MolFromSmiles("CCB1C(CC)C(C)[Si](C)(C)N1C.O=C[Fe](C=O)C=O")
mol9a=Chem.MolFromSmiles("C=C[SiH](C1CCCCC1CN(C)C)[Fe](C=O)(C=O)(C=O)C=O")
mol10a=Chem.MolFromSmiles("CC(C)C1CCCC(C(C)C)C1[Se][Fe]([Se]C1C(C(C)C)CCCC1C(C)C)(<-[PH](C)(C)C1CCCCC1)<-[PH](C)(C)C1CCCCC1")
mol11a=Chem.MolFromSmiles("CCOC(=O)C12C34CCCCCCC(O3)(C3CCCCC34)C1(C(=O)OCC)[Fe]2(C=O)(C=O)C=O")
mol12a=Chem.MolFromSmiles("O=C[Fe](C=O)(C=O)C12C3C=CC1(N1CCCCC1)C=CC2(N1CCCCC1)CC3")
mol13a=Chem.MolFromSmiles("CC1C(C)C(C)C(C)C1C.C[Si](C)(C)C#CC1CCC(C#C[Fe](C=O)C=O)CC1")
mol14a=Chem.MolFromSmiles("CN(C)P(=O)(C[PH](C=C[Fe](C=O)(C=O)(C=O)C=O)(N(C)C)N(C)C)N(C)C")
mol15a=Chem.MolFromSmiles("C1CCC(CN2CC3CCCCC3C3CCCCC3C2)NC1.Cl[Fe]Cl")

# %%
# # b is for OpenBABEL

# mol1b=Chem.MolFromSmiles("CN1[CH]N([Fe](N=C=S)(N=C=S)(N2[CH]N(C)C=C2)(N2[CH]N(C)C=C2)N2[CH]N(C)C=C2)C=C1")
# mol2b=Chem.MolFromSmiles("CCCC(=O)N1C2=CCC=CN2[Fe]2(N=C=S)(N=C=S)(N3C=CCC=C13)N1C=CCC=C1N(C(=O)CCC)C1=CCC=CN12")
# mol3b=Chem.MolFromSmiles("[O][C][Fe](P)([C][O])([C][O])[C][O]")
# mol4b=Chem.MolFromSmiles("Cc1cc(C)c(N2C=CN(c3c(C)cc(C)cc3C)[Fe]2(Cl)Cl)c(C)c1")
# mol5b=Chem.MolFromSmiles("Cc1cc(C)c(-c2ccc(C3(C)c4ccc(-c5c(C)cc(C)cc5C)n4[Fe](N4C=C[CH]C=C4)(N4C=C[CH]C=C4)n4c(-c5c(C)cc(C)cc5C)ccc43)[nH]2)c(C)c1")
# mol6b=Chem.MolFromSmiles("C[C]1[C@@]2(C)C(C)=C(C)[C@]1(C)[Fe]21([N][N])[C]2N(C=CN2c2c(C)cc(C)cc2C)CC2=C[CH]C=CN21")
# # mol7b=Chem.MolFromSmiles("CC1=C2[CH]C=CC3=C(C)N(c4c(C(C)C)cccc4C(C)C)[Fe@](C)(N23)N1c1c(C(C)C)cccc1C(C)C")
# mol10b=Chem.MolFromSmiles("CC(C)c1cccc(C(C)C)c1[Se][Fe]([Se]c1c(C(C)C)cccc1C(C)C)([PH](C)(C)c1ccccc1)[PH](C)(C)c1ccccc1")
# mol11b=Chem.MolFromSmiles("CCOC(=O)[C]1[C@](C(=O)OCC)([Fe]([C][O])([C][O])[C][O])[C@]23CCCCCC[C@]1(O2)c1ccccc13")
# mol12b=Chem.MolFromSmiles("[O][C][Fe]([C][O])([C][O])[C@@]12[C]3[CH][CH][C@]1(N1CCCCC1)C=C[C@]2(N1CCCCC1)C=C3")
# mol13b=Chem.MolFromSmiles("CC1=C(C)C(C)([Fe]([C][O])([C][O])C#Cc2ccc(C#C[Si](C)(C)C)cc2)C(C)=C1C")
# mol14b=Chem.MolFromSmiles("CN(C)P(=O)(C[PH](C#C[Fe]([C][O])([C][O])([C][O])[C][O])(N(C)C)N(C)C)N(C)C")
# mol15b=Chem.MolFromSmiles("Cl[Fe]Cl.c1ccc(CN2Cc3ccccc3-c3ccccc3C2)nc1")

# %%
# b is for OpenBABEL, this with dative

mol1b=Chem.MolFromSmiles("CN1[CH]N([Fe](N=C=S)(N=C=S)(N2[CH]N(C)C=C2)(N2[CH]N(C)C=C2)N2[CH]N(C)C=C2)C=C1")
mol2b=Chem.MolFromSmiles("CCCC(=O)N1C2=CCC=CN2[Fe]2(N=C=S)(N=C=S)(N3C=CCC=C13)N1C=CCC=C1N(C(=O)CCC)C1=CCC=CN12")
mol3b=Chem.MolFromSmiles("OC[Fe](P)(CO)(CO)CO")
mol4b=Chem.MolFromSmiles("Cc1cc(C)c(N2C=CN(c3c(C)cc(C)cc3C)[Fe]2(Cl)Cl)c(C)c1")
mol5b=Chem.MolFromSmiles("Cc1cc(C)c(-c2ccc(C3(C)c4ccc(-c5c(C)cc(C)cc5C)n4[Fe](N4C=C[CH]C=C4)(N4C=C[CH]C=C4)n4c(-c5c(C)cc(C)cc5C)ccc43)[nH]2)c(C)c1")
mol6b=Chem.MolFromSmiles("CC1=C(C)[C@@]2(C)C(C)[C@]1(C)[Fe]21(NN)C2N(C=CN2c2c(C)cc(C)cc2C)CC2=C[CH]C=CN21")
mol7b=Chem.MolFromSmiles("CC1=C2[CH]C=CC3=C(C)N(c4c(C(C)C)cccc4C(C)C)[Fe@](C)(N23)N1c1c(C(C)C)cccc1C(C)C")
mol10b=Chem.MolFromSmiles("CC(C)c1cccc(C(C)C)c1[Se][Fe]([Se]c1c(C(C)C)cccc1C(C)C)(<-[PH](C)(C)c1ccccc1)<-[PH](C)(C)c1ccccc1")
mol11b=Chem.MolFromSmiles("CCOC(=O)C1[C@](C(=O)OCC)([Fe](CO)(CO)CO)[C@]23CCCCCC[C@]1(O2)c1ccccc13")
mol12b=Chem.MolFromSmiles("OC[Fe](CO)(CO)[C@@]12C3[CH][CH][C@]1(N1CCCCC1)C=C[C@]2(N1CCCCC1)C=C3")
mol13b=Chem.MolFromSmiles("CC1=C(C)C(C)([Fe](C#Cc2ccc(C#C[Si](C)(C)C)cc2)(CO)CO)C(C)=C1C")
mol14b=Chem.MolFromSmiles("CN(C)P(=O)(C[PH](C#C[Fe](CO)(CO)(CO)CO)(N(C)C)N(C)C)N(C)C")
mol15b=Chem.MolFromSmiles("Cl[Fe]Cl.c1ccc(CN2Cc3ccccc3-c3ccccc3C2)nc1")

# %%
def view_difference(mol1, mol2):
    mcs = rdFMCS.FindMCS([mol1,mol2])
    mcs_mol = Chem.MolFromSmarts(mcs.smartsString)
    match1 = mol1.GetSubstructMatch(mcs_mol)
    target_atm1 = []
    for atom in mol1.GetAtoms():
        if atom.GetIdx() not in match1:
            target_atm1.append(atom.GetIdx())
    match2 = mol2.GetSubstructMatch(mcs_mol)
    target_atm2 = []
    for atom in mol2.GetAtoms():
        if atom.GetIdx() not in match2:
            target_atm2.append(atom.GetIdx())
    return Draw.MolsToGridImage([mol1, mol2],highlightAtomLists=[target_atm1, target_atm2])

# %% [markdown]
# ### ID 1 | 55
# ### CSD_code = DEDLUV | q = 0 | S = 0 | Stoichiometry = C18H24FeN10S2 | MND = 6

# %%
Chem.MolToSmiles(mol1a), Chem.MolToSmiles(mol1b)
# Out:
# ('CN1C=CNC1.CN1C=CNC1.CN1C=CNC1.CN1C=CNC1.S=C=N[Fe]N=C=S',
#  'CN1[CH]N([Fe](N=C=S)(N=C=S)(N2[CH]N(C)C=C2)(N2[CH]N(C)C=C2)N2[CH]N(C)C=C2)C=C1')

# %%
Draw.MolsToGridImage([mol1a, mol1b])

# %%
view_difference(mol1a,mol1b)

# %% [markdown]
# ### ID 2 | 73
# ### CSD_code = FOSREN | q = 0 | S = 0 | Stoichiometry = C30H30FeN8O2S2 | MND = 6

# %%
Chem.MolToSmiles(mol2a), Chem.MolToSmiles(mol2b)
# Out:
# ('CCCC(=O)N1C2CCCCN2[Fe]2(N=C=S)(N=C=S)(N3CCCCC13)N1CCCCC1N(C(=O)CCC)C1CCCCN12',
#  'CCCC(=O)N1C2=CCC=CN2[Fe]2(N=C=S)(N=C=S)(N3C=CCC=C13)N1C=CCC=C1N(C(=O)CCC)C1=CCC=CN12')

# %%
Draw.MolsToGridImage([mol2a, mol2b])

# %%
view_difference(mol2a, mol2b)

# %% [markdown]
# ### ID 3 | 13
# ### CSD_code = DIRHIX | q = 0 | S = 0 | Stoichiometry = C4H3FeO4P | MND = 5

# %%
Chem.MolToSmiles(mol3a), Chem.MolToSmiles(mol3b)
# Out:
# ('O=C[Fe](<-[PH4])(C=O)(C=O)C=O', 'OC[Fe](P)(CO)(CO)CO')

# %%
Draw.MolsToGridImage([mol3a, mol3b])

# %%
view_difference(mol3a,mol3b)

# %% [markdown]
# ### ID 4 | 49
# ### CSD_code = VIRWEZ | q = 0 | S = 0 | Stoichiometry = C20H24Cl2FeN2 | MND = 4

# %%
Chem.MolToSmiles(mol4a), Chem.MolToSmiles(mol4b)
# Out:
# ('CC1CC(C)C(N2CCN(C3C(C)CC(C)CC3C)[Fe]2(Cl)Cl)C(C)C1',
#  'Cc1cc(C)c(N2C=CN(c3c(C)cc(C)cc3C)[Fe]2(Cl)Cl)c(C)c1')

# %%
Draw.MolsToGridImage([mol4a, mol4b])

# %%
view_difference(mol4a,mol4b)

# %% [markdown]
# ### ID 5 | 110
# ### CSD_code = ERANIV | q = 0 | S = 0 | Stoichiometry = C51H53FeN5 | MND = 4

# %%
Chem.MolToSmiles(mol5a), Chem.MolToSmiles(mol5b)
# Out:
# ('CC1CC(C)C(C2CCC(C3(C)C4CCC(C5C(C)CC(C)CC5C)N4[Fe](N4CCCCC4)(N4CCCCC4)N4C(C5C(C)CC(C)CC5C)CCC43)N2)C(C)C1',
#  'Cc1cc(C)c(-c2ccc(C3(C)c4ccc(-c5c(C)cc(C)cc5C)n4[Fe](N4C=C[CH]C=C4)(N4C=C[CH]C=C4)n4c(-c5c(C)cc(C)cc5C)ccc43)[nH]2)c(C)c1')

# %%
Draw.MolsToGridImage([mol5a, mol5b])

# %%
view_difference(mol5a,mol5b)

# %% [markdown]
# ### ID 6 | 68
# ### CSD_code = VEJDIA | q = 1 | S = 0 | Stoichiometry = C28H34FeN5(1+) | MND = 8

# %%
Chem.MolToSmiles(mol6a), Chem.MolToSmiles(mol6b)
# Out:
# ('CC1C(C)C(C)C(C)C1C.CC1CC(C)C(N2C=CN(CC3CCCCN3)C2[Fe]2N=N2)C(C)C1',
#  'CC1=C(C)[C@@]2(C)C(C)[C@]1(C)[Fe]21(NN)C2N(C=CN2c2c(C)cc(C)cc2C)CC2=C[CH]C=CN21')

# %%
Draw.MolsToGridImage([mol6a, mol6b])

# %%
view_difference(mol6a,mol6b)

# %% [markdown]
# ### ID 10 | 101
# ### CSD_code = YEWSOI | q = 0 | S = 0 | Stoichiometry = C40H56FeP2Se2 | MND = 4

# %%
Chem.MolToSmiles(mol10a), Chem.MolToSmiles(mol10b)
# Out:
# ('CC(C)C1CCCC(C(C)C)C1[Se][Fe]([Se]C1C(C(C)C)CCCC1C(C)C)(<-[PH](C)(C)C1CCCCC1)<-[PH](C)(C)C1CCCCC1',
#  'CC(C)c1cccc(C(C)C)c1[Se][Fe]([Se]c1c(C(C)C)cccc1C(C)C)(<-[PH](C)(C)c1ccccc1)<-[PH](C)(C)c1ccccc1')

# %%
Draw.MolsToGridImage([mol10a, mol10b])

# %%
view_difference(mol10a,mol10b)

# %% [markdown]
# ### ID 11 | 60
# ### CSD_code = VUFNEP | q = 0 | S = 0 | Stoichiometry = C25H26FeO8 | MND = 6

# %%
Chem.MolToSmiles(mol11a), Chem.MolToSmiles(mol11b)
# Out:
# ('CCOC(=O)C12C34CCCCCCC(O3)(C3CCCCC34)C1(C(=O)OCC)[Fe]2(C=O)(C=O)C=O',
#  'CCOC(=O)C1[C@](C(=O)OCC)([Fe](CO)(CO)CO)[C@]23CCCCCC[C@]1(O2)c1ccccc13')

# %%
Draw.MolsToGridImage([mol11a, mol11b])

# %%
view_difference(mol11a,mol11b)

# %% [markdown]
# ### ID 12 | 55
# ### CSD_code = JIZPIR | q = 0 | S = 0 | Stoichiometry = C23H26FeN2O3 | MND = 7

# %%
Chem.MolToSmiles(mol12a), Chem.MolToSmiles(mol12b)
# Out:
# ('O=C[Fe](C=O)(C=O)C12C3C=CC1(N1CCCCC1)C=CC2(N1CCCCC1)CC3',
#  'OC[Fe](CO)(CO)[C@@]12C3[CH][CH][C@]1(N1CCCCC1)C=C[C@]2(N1CCCCC1)C=C3')

# %%
Draw.MolsToGridImage([mol12a, mol12b])

# %%
view_difference(mol12a,mol12b)

# %% [markdown]
# ### ID 13 | 57
# ### CSD_code = ZUHJOD | q = 0 | S = 0 | Stoichiometry = C25H28FeO2Si | MND = 8

# %%
Chem.MolToSmiles(mol13a), Chem.MolToSmiles(mol13b)
# Out:
# ('CC1C(C)C(C)C(C)C1C.C[Si](C)(C)C#CC1CCC(C#C[Fe](C=O)C=O)CC1',
#  'CC1=C(C)C(C)([Fe](C#Cc2ccc(C#C[Si](C)(C)C)cc2)(CO)CO)C(C)=C1C')

# %%
Draw.MolsToGridImage([mol13a, mol13b])

# %%
view_difference(mol13a,mol13b)

# %% [markdown]
# ### ID 14 | 53
# ### CSD_code = TAYPAK | q = 0 | S = 0 | Stoichiometry = C15H26FeN4O5P2 | MND = 5

# %%
Chem.MolToSmiles(mol14a), Chem.MolToSmiles(mol14b)
# Out:
# ('CN(C)P(=O)(C[PH](C=C[Fe](C=O)(C=O)(C=O)C=O)(N(C)C)N(C)C)N(C)C',
#  'CN(C)P(=O)(C[PH](C#C[Fe](CO)(CO)(CO)CO)(N(C)C)N(C)C)N(C)C')

# %%
Draw.MolsToGridImage([mol14a, mol14b])

# %%
view_difference(mol14a,mol14b)

# %% [markdown]
# ### ID 15 | 43
# ### CSD_code = QEBVUR | q = 0 | S = 0 | Stoichiometry = C20H18Cl2FeN2 | MND = 4

# %%
Chem.MolToSmiles(mol15a), Chem.MolToSmiles(mol15b)
# Out:
# ('C1CCC(CN2CC3CCCCC3C3CCCCC3C2)NC1.Cl[Fe]Cl',
#  'Cl[Fe]Cl.c1ccc(CN2Cc3ccccc3-c3ccccc3C2)nc1')

# %%
Draw.MolsToGridImage([mol15a, mol15b])

# %%
view_difference(mol15a,mol15b)

# %%
# Draw.MolsToGridImage([mol1a, mol1b])

# %%
# view_difference(mol1a,mol1b)

# %%
# Draw.MolsToGridImage([mol1a, mol1b])

# %%
# view_difference(mol1a,mol1b)

# %%
# Draw.MolsToGridImage([mol1a, mol1b])

# %%
# view_difference(mol1a,mol1b)

# %%
# Draw.MolsToGridImage([mol1a, mol1b])

# %%
# view_difference(mol1a,mol1b)
